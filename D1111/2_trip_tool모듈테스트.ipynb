# %%
from mylib import trip_tool_Agent as tta

# %%
user_input='2025년 12월 서울에서 열리는 축제 알려줘'
# user_input='방금 무슨 얘기 했지?'
ai_result = tta.run_agent_memory(user_input=user_input, thread_id='1001')
print(ai_result)
# Out:
# ...
# 👤 사용자: 2025년 12월 서울에서 열리는 축제 알려줘
# ...
# 2025-11-12 10:37:09,039 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-12 10:37:09,114 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2025-11-12 10:37:14,959 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-12 10:37:14,987 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2025-11-12 10:37:17,582 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# 🤖 어시스턴트:
# ...

# %%
# user_input='2025년 12월 서울에서 열리는 축제 알려줘'
user_input='방금 무슨 얘기 했지?'
ai_result = tta.run_agent_memory(user_input=user_input, thread_id='1001')
print(ai_result)
# Out:
# ...
# 👤 사용자: 방금 무슨 얘기 했지?
# ...
# 2025-11-12 10:37:25,939 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# 🤖 어시스턴트:
# ...
