# %%
from mylib import trip_tool as tt

# %%
session_id = "user_1234"
user_input = '2025년 12월 서울에서 열리는 축제 알려줘'
# user_input = '구체적인 일정 알려줘'
ai_result = tt.run_agent(user_input=user_input, session_id=session_id)
print(ai_result)
# Out:
# ...
#  👤 사용자: 2025년 12월 서울에서 열리는 축제 알려줘
# ...
# 2025-11-11 13:47:58,155 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
#
# 현재 서울의 날짜와 시간은 2025년 11월 11일 오후 1시 47분입니다.
#
# 서울의 현재 날씨는 다음과 같습니다:
# - 기온: 13.76도
# - 체감 기온: 12.34도
# - 습도: 44%
# - 바람: 3.09m/s (북서쪽)
# - 날씨: 맑음
# - 가시거리: 10,000m
#
# 더 궁금한 점이나 다른 지역의 정보가 필요하시면 알려주세요!
