# %%
# !python au_responseV3.py
# Out:
# python: can't open file 'c:\\Class250615\\llm_Workspace\\D1106\\au_responseV3.py': [Errno 2] No such file or directory

# %%
from ai_responseV3 import get_ai_response_tools, get_followup_response_tools, get_first_response_tools, tools
from ai_responseV2 import get_current_date_tz, get_current_time_tz

# %%
question = '뉴욕과 시카고의 시차를 알려줘'
response = get_ai_response_tools(question)
print(f'💬AI : {response}')
# Out:
# log : 현재 시간 : 04:05:15 America/New_York
# log : 현재 시간 : 03:05:15 America/Chicago
# 💬AI : 뉴욕과 시카고의 현재 시각 차이는 1시간입니다. 지금 뉴욕은 04:05:15이고, 시카고는 03:05:15입니다. 따라서 시카고가 뉴욕보다 1시간 늦습니다.
