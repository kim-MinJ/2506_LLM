# %%
# !python ai_responseV2.py

# %%
from ai_responseV2 import get_ai_response, get_first_response_tz, get_followup_response_tz

# %%
question =  '뉴욕은 몇시야?' #'서울은 어느 나라야?'
response = get_first_response_tz(question)
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-CYoLIwxBdegowzRnrzL7zktjQLDsE",
#   "choices": [
#     {
#       "finish_reason": "function_call",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": null,
#         "refusal": null,
#         "role": "assistant",
#         "annotations": [],
#         "audio": null,
#         "function_call": {
#           "arguments": "{\"timezone\":\"America/New_York\"}",
#           "name": "get_current_time_tz"
#         },
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1762412704,
#   "model": "gpt-4o-2024-08-06",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_cbf1785567",
#   "usage": {
#     "completion_tokens": 20,
#     "prompt_tokens": 163,
#     "total_tokens": 183,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": 0,
#       "cached_tokens": 0
#     }
#   }
# }

# %%
import json
from ai_responseV2 import get_current_time_tz, get_current_date_tz
fn_name = getattr(response.choices[0].message.function_call, "name", None)
tz = json.loads(response.choices[0].message.function_call.arguments)
print(f'log tz : {tz}')
func_response =  globals()[fn_name](**tz)  
print(f'log func_response : {func_response}')
followup_response=get_followup_response_tz(fn_name,func_response)
# Out:
# log tz : {'timezone': 'America/New_York'}
# log : 현재 시간 : 02:05:08 America/New_York
# log func_response : 02:05:08

# %%
question = '뉴욕의 날짜와 시간을 알려줘?' #'서울은 어느 나라야?'
final_response = get_ai_response(question)
print(f'💬AI : {final_response}')
# Out:
# log : 현재 날짜 : 2025 년 11 월 06 일 America/New_York
# 💬AI : 오늘의 날짜는 2025년 11월 6일입니다. 다른 정보나 도움이 필요하시면 말씀해 주세요!

# %%
question = '뉴욕은 지금 몇일 이야?'  #'서울은 어느 나라야?'
final_response = get_ai_response(question)
print(f'💬AI : {final_response}')
# Out:
# log : 현재 날짜 : 2025 년 11 월 06 일 America/New_York
# 💬AI : 오늘은 2025년 11월 6일입니다. 어떤 계획이 있으신가요?
