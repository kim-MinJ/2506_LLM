# %%
from mylib import langchain_tool_weather as ask

# %%
ai_response = ask.ask_weather('서울시 구로구 날씨 알려줘')
# Out:
# 2025-11-10 14:47:28,107 - INFO -
# ============================================================
# 2025-11-10 14:47:28,107 - INFO - 🔵 사용자 질문: 서울시 구로구 날씨 알려줘
# 2025-11-10 14:47:28,108 - INFO - ============================================================
# 2025-11-10 14:47:28,658 - INFO - 날씨 에이전트 설정 완료
# 2025-11-10 14:47:28,659 - INFO - 메시지 초기화 완료
# 2025-11-10 14:47:29,755 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 14:47:29,790 - INFO - 응답 받음 - tool_calls: 1개
# 2025-11-10 14:47:29,793 - INFO - 도구 호출 발견: 1개
# 2025-11-10 14:47:29,794 - INFO - 도구 실행: get_coordinates
# 2025-11-10 14:47:29,795 - INFO -   - ID: call_uFFplafImaCtb0t3rZeP4qDe
# 2025-11-10 14:47:29,798 - INFO -   - Args: {'location': '서울시 구로구'}
# 2025-11-10 14:47:30,743 - INFO - 서울시 구로구의 위도: 37.4951999, 경도: 126.8877000
# 2025-11-10 14:47:30,752 - INFO - ✅도구 실행 결과: 37.4951999,126.8877000...
# 2025-11-10 14:47:30,755 - INFO - 🟢 messages:SystemMessage
# 	HumanMessage
# 	AIMessage
# 	ToolMessage
# 2025-11-10 14:47:30,757 - INFO - ============================================================
# 2025-11-10 14:47:31,570 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 14:47:31,581 - INFO - 응답 받음 - tool_calls: 1개
# 2025-11-10 14:47:31,583 - INFO - 도구 호출 발견: 1개
# 2025-11-10 14:47:31,586 - INFO - 도구 실행: get_weather_info
# 2025-11-10 14:47:31,588 - INFO -   - ID: call_YNILmbcvqa716E44EHNt2SQn
# 2025-11-10 14:47:31,590 - INFO -   - Args: {'lat_lon': '37.4951999,126.8877000'}
# 2025-11-10 14:47:31,789 - INFO - 날씨 정보 조회 성공: Kwangmyŏng
# 2025-11-10 14:47:31,790 - INFO - ✅도구 실행 결과: 날씨: 맑음
# 기온(°C): 10.98°C
# 체감온도(°C): 8.76°C
# 습도(%): 24%
# 지역: Kwangmyŏng...
# 2025-11-10 14:47:31,792 - INFO - 🟢 messages:SystemMessage
# 	HumanMessage
# 	AIMessage
# 	ToolMessage
# 	AIMessage
# 	ToolMessage
# 2025-11-10 14:47:31,793 - INFO - ============================================================
# 2025-11-10 14:47:33,528 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
print(f'💬AI : {ai_response}')
# Out:
# 💬AI : 서울시 구로구의 현재 날씨는 🌞 맑음이며, 기온은 약 11도(체감온도 8.8도)입니다. 습도는 24%로 건조한 편이에요. 좋은 하루 보내세요! 😊

# %%
ai_response = ask.ask_weather(user_question='AI Agents 설명해줘')
print(f'💬AI : {ai_response}')
# Out:
# 2025-11-10 14:47:33,566 - INFO -
# ============================================================
# 2025-11-10 14:47:33,567 - INFO - 🔵 사용자 질문: AI Agents 설명해줘
# 2025-11-10 14:47:33,568 - INFO - ============================================================
# 2025-11-10 14:47:33,575 - INFO - 날씨 에이전트 설정 완료
# 2025-11-10 14:47:33,575 - INFO - 메시지 초기화 완료
# 2025-11-10 14:47:37,111 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 💬AI : AI Agents는 인공지능 시스템 내에서 특정 작업이나 목적을 수행하기 위해 설계된 독립적인 주체를 의미해요. 이러한 에이전트는 주어진 환경에서 데이터를 감지하고, 분석하며, 의사결정을 하고, 행동을 취하는 능력을 갖추고 있답니다.
#
# 주요 특징은 다음과 같아요:
# 1. **자율성:** 스스로 판단하고 행동할 수 있어요.
# 2. **환경 인식:** 주변 환경을 감지하고 이해해요.
# 3. **목표 지향적:** 특정 목적을 달성하기 위해 행동해요.
# 4. **학습 능력:** 경험을 통해 점점 더 나은 결정을 내릴 수 있어요.
#
# 예를 들어, 챗봇, 자율주행차, 로봇, 게임 속 캐릭터 등이 AI 에이전트에 해당해요. 이런 에이전트들은 프로그래밍된 규칙이나 머신러닝, 강화학습 등의 기법으로 학습하며 환경과 상호작용한답니다.
#
# 혹시 특정 분야의 AI 에이전트에 대해 더 궁금한 점이 있나요? 😊

# %%
ai_response = ask.ask_weather(user_question = '서울과 도쿄의 날씨 비교해줘')
print(f"AI : {ai_response}")
# Out:
# 2025-11-10 14:47:37,158 - INFO -
# ============================================================
# 2025-11-10 14:47:37,159 - INFO - 🔵 사용자 질문: 서울과 도쿄의 날씨 비교해줘
# 2025-11-10 14:47:37,160 - INFO - ============================================================
# 2025-11-10 14:47:37,171 - INFO - 날씨 에이전트 설정 완료
# 2025-11-10 14:47:37,172 - INFO - 메시지 초기화 완료
# 2025-11-10 14:47:38,215 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 14:47:38,226 - INFO - 응답 받음 - tool_calls: 2개
# 2025-11-10 14:47:38,228 - INFO - 도구 호출 발견: 2개
# 2025-11-10 14:47:38,230 - INFO - 도구 실행: get_coordinates
# 2025-11-10 14:47:38,231 - INFO -   - ID: call_Anry9kUC35gmaSrs0JI6OA63
# 2025-11-10 14:47:38,232 - INFO -   - Args: {'location': '서울'}
# 2025-11-10 14:47:39,277 - INFO - 서울의 위도: 37.5666791, 경도: 126.9782914
# 2025-11-10 14:47:39,282 - INFO - ✅도구 실행 결과: 37.5666791,126.9782914...
# 2025-11-10 14:47:39,285 - INFO - 도구 실행: get_coordinates
# 2025-11-10 14:47:39,287 - INFO -   - ID: call_4y7VVLGWAsgFHPCUcfSeradN
# 2025-11-10 14:47:39,288 - INFO -   - Args: {'location': '도쿄'}
# 2025-11-10 14:47:40,353 - INFO - 도쿄의 위도: 35.6812546, 경도: 139.7667060
# 2025-11-10 14:47:40,360 - INFO - ✅도구 실행 결과: 35.6812546,139.7667060...
# 2025-11-10 14:47:40,363 - INFO - 🟢 messages:SystemMessage
# 	HumanMessage
# 	AIMessage
# 	ToolMessage
# 	ToolMessage
# 2025-11-10 14:47:40,366 - INFO - ============================================================
# 2025-11-10 14:47:41,754 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 14:47:41,771 - INFO - 응답 받음 - tool_calls: 2개
# 2025-11-10 14:47:41,772 - INFO - 도구 호출 발견: 2개
# 2025-11-10 14:47:41,773 - INFO - 도구 실행: get_weather_info
# 2025-11-10 14:47:41,773 - INFO -   - ID: call_GAFbMz4XAxoEfdt821zfzkSn
# 2025-11-10 14:47:41,774 - INFO -   - Args: {'lat_lon': '37.5666791,126.9782914'}
# 2025-11-10 14:47:41,971 - INFO - 날씨 정보 조회 성공: Seoul
# 2025-11-10 14:47:41,973 - INFO - ✅도구 실행 결과: 날씨: 맑음
# 기온(°C): 10.76°C
# 체감온도(°C): 8.52°C
# 습도(%): 24%
# 지역: Seoul...
# 2025-11-10 14:47:41,974 - INFO - 도구 실행: get_weather_info
# 2025-11-10 14:47:41,975 - INFO -   - ID: call_TS55XQwthZTen8r6FoIFBrg6
# 2025-11-10 14:47:41,977 - INFO -   - Args: {'lat_lon': '35.6812546,139.7667060'}
# 2025-11-10 14:47:42,154 - INFO - 날씨 정보 조회 성공: Marunouchi
# 2025-11-10 14:47:42,155 - INFO - ✅도구 실행 결과: 날씨: 실 비
# 기온(°C): 18.51°C
# 체감온도(°C): 17.49°C
# 습도(%): 41%
# 지역: Marunouchi...
# 2025-11-10 14:47:42,156 - INFO - 🟢 messages:SystemMessage
# 	HumanMessage
# 	AIMessage
# 	ToolMessage
# 	ToolMessage
# 	AIMessage
# 	ToolMessage
# 	ToolMessage
# 2025-11-10 14:47:42,157 - INFO - ============================================================
# 2025-11-10 14:47:45,881 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# AI : 서울과 도쿄의 현재 날씨를 비교해 드릴게요! 🌤️
#
# - 서울
#   - 날씨: 맑음 ☀️
#   - 기온: 10.76°C
#   - 체감온도: 8.52°C
#   - 습도: 24%
#
# - 도쿄 (마루노우치 지역)
#   - 날씨: 실 비 🌧️
#   - 기온: 18.51°C
#   - 체감온도: 17.49°C
#   - 습도: 41%
#
# 서울은 맑고 쌀쌀한 편이고, 도쿄는 비가 오면서 기온이 더 높고 습도가 좀 더 높아요. 두 지역 모두 외출 시 옷차림에 참고하세요! 😊
