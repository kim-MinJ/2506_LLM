# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# 랭체인으로 모델 객체 생성
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-mini")

# %%
# 프롬프트 role : HumanMessage, SystemMessage, AIMessage 객체로 저장 할 수 있음.
# 요청 보내는 메소드 : invoke()
from langchain_core.messages import HumanMessage
ai_message = llm.invoke([HumanMessage(content="안녕? 나는 김땡땡이야. 반가워")])
ai_message
# Out:
# AIMessage(content='안녕, 김땡땡씨! 만나서 반가워요. 어떻게 도와줄까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 24, 'total_tokens': 49, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAjVArbdVQ5WL6Z7odDwqBYsYEhX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ebfb3729-d89c-4750-a07f-c5400e604a43-0', usage_metadata={'input_tokens': 24, 'output_tokens': 25, 'total_tokens': 49, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
llm.invoke([HumanMessage(content='내 이름을 알려줬는데 기억하니?')])
# Out:
# AIMessage(content='아쉽게도 대화가 초기화되면 이전에 주고받은 내용은 기억하지 못해요. 다시 한번 이름을 알려주시면 기억하는 동안 대화에 활용할 수 있어요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 18, 'total_tokens': 62, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAjpDW4eKnU3KNl4CyDguUxhDrRH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--615cfa6f-75ae-4d3e-aff6-ef9037af9531-0', usage_metadata={'input_tokens': 18, 'output_tokens': 44, 'total_tokens': 62, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.messages import AIMessage, SystemMessage

# %%
messages = [
    SystemMessage("너는 사용자를 도와주는 상담사야."),  # 초기 시스템 메시지
]

# %%
isPrint=True
while True:
    user_input = input("사용자: ")  # 1. 사용자 입력 받기

    if user_input == "exit":  #2.사용자가 대화를 종료하려는지 확인인
        break
    # 랭체인의 메시지 기록(히스토리) 기능
    messages.append(
        HumanMessage(user_input)
    )  # 사용자 메시지를 대화 기록에 추가 
    
    ai_response = llm.invoke(messages)  # 대화 기록을 기반으로 AI 응답 가져오기
    if isPrint:
      print(f"log ai_response ➡ {ai_response.model_dump_json(indent=2)}")
      isPrint=False
    messages.append(
        ai_response
    )  # AI 응답 대화 기록에 추가하기

    print("AI: " + ai_response.content)  # AI 응답 출력
# Out:
# log ai_response ➡ {
#   "content": "안녕하세요! 필요하실 때 언제든 말씀해 주세요. 도움이 되어드리겠습니다.",
#   "additional_kwargs": {
#     "refusal": null
#   },
#   "response_metadata": {
#     "token_usage": {
#       "completion_tokens": 19,
#       "prompt_tokens": 855,
#       "total_tokens": 874,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-4.1-mini-2025-04-14",
#     "system_fingerprint": "fp_4c2851f862",
#     "id": "chatcmpl-CaB4dPkUC6XkF9OnKmukJ8J8p34Uw",
#     "service_tier": "default",
#     "finish_reason": "stop",
#     "logprobs": null
#   },
#   "type": "ai",
#   "name": null,
#   "id": "lc_run--67f835d7-4ca2-454a-8280-fefd955b59e0-0",
#   "tool_calls": [],
#   "invalid_tool_calls": [],
#   "usage_metadata": {
#     "input_tokens": 855,
#     "output_tokens": 19,
#     "total_tokens": 874,
#     "input_token_details": {
#       "audio": 0,
#       "cache_read": 0
#     },
#     "output_token_details": {
#       "audio": 0,
#       "reasoning": 0
#     }
#   }
# }
# AI: 안녕하세요! 필요하실 때 언제든 말씀해 주세요. 도움이 되어드리겠습니다.

# %%
print(f'{message.__class_getitem__}\n' for message in messages)
# Out:
# <generator object <genexpr> at 0x0000017F420B3E00>

# %%
messages
# Out:
# [SystemMessage(content='너는 사용자를 도와주는 상담사야.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='나는 김땡땡이야 안녕', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='안녕하세요, 김땡땡님! 만나서 반갑습니다. 오늘 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 34, 'total_tokens': 60, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAq6Y16klvmMGVRjHnQbfBada9C5', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--9cb04a57-3571-4cf4-9405-cca7b684df52-0', usage_metadata={'input_tokens': 34, 'output_tokens': 26, 'total_tokens': 60, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='내 이름 기억해?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='네, 김땡땡님 이름 기억하고 있습니다! 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 73, 'total_tokens': 95, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAqInqDGp00VGGarIxfxcHzTR0nV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--8935c02c-fb7e-409d-b9d3-ce6dc7e00697-0', usage_metadata={'input_tokens': 73, 'output_tokens': 22, 'total_tokens': 95, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='피자먹고싶은데 피자 추천 좀 해봐 가격은 얼마야?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='김땡땡님, 피자 추천해드릴게요!\n\n1. 마르게리타 피자  \n- 맛: 신선한 토마토 소스와 모짜렐라 치즈, 바질의 조화로 깔끔하고 담백한 맛  \n- 가격: 대략 15,000원 ~ 20,000원\n\n2. 페퍼로니 피자  \n- 맛: 매콤한 페퍼로니가 듬뿍 올라간 클래식한 피자  \n- 가격: 대략 18,000원 ~ 23,000원\n\n3. 하와이안 피자  \n- 맛: 달콤한 파인애플과 햄이 어우러져 독특하고 상큼한 맛  \n- 가격: 대략 17,000원 ~ 22,000원\n\n지역이나 브랜드에 따라 가격 차이가 있을 수 있으니, 근처 피자 가게나 앱에서 확인해 보시면 좋아요! 더 필요한 정보 있으면 말씀해 주세요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 221, 'prompt_tokens': 121, 'total_tokens': 342, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAqbetT4x7ZNuAw3OlJ4Bni7ZBWs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--56d4bf0a-d259-4a33-96ea-4fca48e41b8e-0', usage_metadata={'input_tokens': 121, 'output_tokens': 221, 'total_tokens': 342, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='김땡땡님, 추가로 궁금한 점이나 다른 추천 원하시면 언제든 말씀해 주세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 350, 'total_tokens': 377, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAqoDu8FtO5xCkZMPWHPMxwVrHmI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--0814ca50-2fd8-425b-b806-96211e221b2e-0', usage_metadata={'input_tokens': 350, 'output_tokens': 27, 'total_tokens': 377, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='안녕 내 이름 기억해?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='네, 김땡땡님! 이름 기억하고 있습니다. 오늘도 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 392, 'total_tokens': 417, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAxrC0QiJNlANVaZvs215FHmcG9i', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--4c022491-de16-4e14-ad94-001f7baac2d2-0', usage_metadata={'input_tokens': 392, 'output_tokens': 25, 'total_tokens': 417, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='너가 날 어떻게 기억하는거야?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='저는 대화 중에 사용자가 알려주신 이름이나 정보를 기억해서 대화를 이어갈 수 있어요. 하지만 대화가 끝나면 개인정보를 따로 저장하지 않고, 새 대화가 시작되면 이전 정보를 기억하지 못한답니다. 그래서 지금은 김땡땡님이라고 기억하고 있지만, 다음에 다시 대화하면 새롭게 알려주셔야 해요! 더 궁금한 점 있으면 알려주세요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 434, 'total_tokens': 530, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAyNGyu06M0rOq7KxwLbs5wRUVdF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--8bf2b348-4738-42f2-aad4-6b40a174751d-0', usage_metadata={'input_tokens': 434, 'output_tokens': 96, 'total_tokens': 530, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='내 이름 기억해?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='네, 지금 대화 중에는 김땡땡님 이름 기억하고 있습니다! 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 543, 'total_tokens': 570, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAyfehYMGHD06i5jFDGvP1Qcl6Kh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--05f85ab6-5015-4802-9706-4067dad838ea-0', usage_metadata={'input_tokens': 543, 'output_tokens': 27, 'total_tokens': 570, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='내 이름은 김민민이야', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='알겠습니다, 김민민님! 이제부터 김민민님이라고 부를게요. 무엇을 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 590, 'total_tokens': 618, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAyyirLpYCjzazLA5Vvum5lDzrzJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--896a2353-f21e-4456-bfe5-03516c848a2c-0', usage_metadata={'input_tokens': 590, 'output_tokens': 28, 'total_tokens': 618, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='그 전에 말했던 이름은 뭐였지?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='앞서 대화에서 알려주신 이름은 김땡땡님이었어요. 지금은 김민민님으로 기억하고 있습니다! 다른 질문이나 도움이 필요하시면 언제든 말씀해 주세요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 636, 'total_tokens': 682, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAz8VxQEcbF5GOi6TgDcIO4xKhre', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--1dd47df2-14cd-49f6-ad7f-3d74cb4becd3-0', usage_metadata={'input_tokens': 636, 'output_tokens': 46, 'total_tokens': 682, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='김민민님, 추가로 궁금한 점 있으면 언제든 말씀해 주세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 690, 'total_tokens': 709, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaAzDUFhyOWAEYpY96pGLOMn6iTlE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--13bfec5b-94a1-4a97-ba9e-8a7fc0eae550-0', usage_metadata={'input_tokens': 690, 'output_tokens': 19, 'total_tokens': 709, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='나는 김땡땡이야 나이는 30살이야', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='네, 김땡땡님! 30살이시군요. 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 734, 'total_tokens': 760, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaB1fvalLFqvhKuwnmAL9fGIHHFba', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--41843a3d-c1f9-41de-a9d2-968e1419ddd1-0', usage_metadata={'input_tokens': 734, 'output_tokens': 26, 'total_tokens': 760, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='내 나이가 몇 살이지?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='김땡땡님, 말씀해 주신 대로 30살이세요. 더 궁금한 점 있으시면 언제든 물어보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 775, 'total_tokens': 810, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaB1nYYsPihRu4iF7TnmgTyLEGMQV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--07cc00cf-80eb-41af-9d50-7f09457d53d7-0', usage_metadata={'input_tokens': 775, 'output_tokens': 35, 'total_tokens': 810, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='좋아 exit', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='네, 김땡땡님! 언제든 필요하실 때 다시 찾아주세요. 좋은 하루 보내세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 821, 'total_tokens': 847, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaB21iEN3jz5jukRDda5JRj8kubWJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--cab4c0ea-6354-41df-8b6d-b1796acd457c-0', usage_metadata={'input_tokens': 821, 'output_tokens': 26, 'total_tokens': 847, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='안녕하세요! 필요하실 때 언제든 말씀해 주세요. 도움이 되어드리겠습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 855, 'total_tokens': 874, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-CaB4dPkUC6XkF9OnKmukJ8J8p34Uw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--67f835d7-4ca2-454a-8280-fefd955b59e0-0', usage_metadata={'input_tokens': 855, 'output_tokens': 19, 'total_tokens': 874, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
